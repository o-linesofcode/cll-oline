# %% [markdown]
# For this sketch, I wanted to generate random letters and spell out the letters S, T, O, P one by one so when its prints with delays and scrolls down it gives the illusion of the letter stopping andf

# %%
import unicodedata

# %%
import random

# %%
import time

# %%
period = random.randrange(0x0021, 0x007F)

while (period != 0x002E):
    print('  S  ', '  T   ', chr(period) ,'   P  ')
    period = random.randrange(0x0021, 0x007F)

print('  S  ', '  T   ', chr(period) ,'   P  ')
    


#for i in range(10):
#    print('  S  ', '  T  ', chr(period) ,'  P  ')
# Out:
#   S     T    o    P
#   S     T    G    P
#   S     T    '    P
#   S     T    E    P
#   S     T    7    P
#   S     T    '    P
#   S     T    {    P
#   S     T    ?    P
#   S     T    Q    P
#   S     T    3    P
#   S     T    z    P
#   S     T    7    P
#   S     T    5    P
#   S     T    A    P
#   S     T    m    P
#   S     T    /    P
#   S     T    N    P
#   S     T    (    P
#   S     T    p    P
#   S     T    9    P
#   S     T    W    P
#   S     T    U    P
#   S     T    ]    P
#   S     T    @    P
#   S     T    y    P
#   S     T    -    P
#   S     T    S    P
#   S     T    $    P
#   S     T    >    P
#   S     T    x    P
#   S     T    =    P
#   S     T    k    P
#   S     T    [    P
#   S     T    f    P
#   S     T    \    P
#   S     T    [    P
#   S     T    C    P
#   S     T    q    P
#   S     T    *    P
#   S     T    W    P
#   S     T    )    P
#   S     T    0    P
#   S     T    s    P
#   S     T    X    P
#   S     T    #    P
# ...

# %%
ch1 = 0x0021
ch2 = 0x0024
ch3 = 0x0022
ch4 = 0x0023

for i in range(1900):
    if ch1!=0x0053:
        ch1 = random.randrange(0x0021, 0x047f)  
    else:
        ch1 = 0x0053

    if ch2!=0x0054:
        ch2 = random.randrange(0x0021, 0x047f)  
    else:
        ch2 = 0x0054

    if ch3!=0x004F:
        ch3 = random.randrange(0x0021, 0x047f)  
    else:
        ch3 = 0x004F

    if ch4!=0x0050:
        ch4 = random.randrange(0x0021, 0x047f)  
    else:
        ch4 = 0x0050

# %%
range1 = 0x0021
range2 = 0x007f
ch1 = random.randrange(range1, range2) 
ch2 = random.randrange(range1, range2) 
ch3 = random.randrange(range1, range2) 
ch4 = random.randrange(range1, range2) 


for i in range(900):
    if ch1!=0x0053:
        ch1 = random.randrange(range1, range2)
        ch2 = random.randrange(range1, range2)
        ch3 = random.randrange(range1, range2)
        ch4 = random.randrange(range1, range2)
    else:
        ch1 = 0x0053
        if ch2!=0x0054:
            ch2 = random.randrange(range1, range2)
            ch3 = random.randrange(range1, range2)
            ch4 = random.randrange(range1, range2) 
        else:
            ch2 = 0x0054
            if ch3!=0x004F:
                ch3 = random.randrange(range1, range2)
                ch4 = random.randrange(range1, range2) 
            else:
                ch3 = 0x004F

                if ch4!=0x0050:
                    ch4 = random.randrange(range1, range2)  
                else:
                    ch4 = 0x0050


        
    print('                       ', chr(ch1), chr(ch2), chr(ch3), chr(ch4))
    #time.sleep(50/1000)
# Out:
#                         Z u / -
#                         2 : ; H
#                         r A M A
#                         Y 4 & %
#                         ; X K q
#                         ' 5 c 7
#                         Q 0 # K
#                         d 0 V d
#                         ^ v j k
#                         p V # s
#                         ; Z J w
#                         . v 9 i
#                         B # ? ;
#                         U K t *
#                         K 0 o O
#                         ! i ? =
#                         H v & J
#                         T e 5 g
#                         W 1 % i
#                         , _ h U
#                         k n J &
#                         ^ R J >
#                         7 Z " >
#                         $ Y O G
#                         } 2 t /
#                         L u { 5
#                         - z E R
#                         ^ D T q
#                         D X F :
# ...

# %%
range1 = 0x0021
range2 = 0x007f
ch1 = random.randrange(range1, range2) 
ch2 = random.randrange(range1, range2) 
ch3 = random.randrange(range1, range2) 
ch4 = random.randrange(range1, range2) 


for i in range(900):
    if ch1!=0x0053:
        ch1 = random.randrange(range1, range2)
        ch2 = random.randrange(range1, range2)
        ch3 = random.randrange(range1, range2)
        ch4 = random.randrange(range1, range2)
    else:
        ch1 = 0x0053
        if ch2!=0x0054:
            ch2 = random.randrange(range1, range2)
            ch3 = random.randrange(range1, range2)
            ch4 = random.randrange(range1, range2) 
        else:
            ch2 = 0x0054
            if ch3!=0x004F:
                ch3 = random.randrange(range1, range2)
                ch4 = random.randrange(range1, range2) 
            else:
                ch3 = 0x004F

                if ch4!=0x0050:
                    ch4 = random.randrange(range1, range2)  
                else:
                    ch4 = 0x0050


        
    print('                       ', chr(ch1), chr(ch2), chr(ch3), chr(ch4))
    time.sleep(50/1000)
# Out:
#                         1 P 3 '
#                         L ` s b
#                         % , z R
#                         ` % \ X
#                         / . ^ %
#                         F < - 8
#                         ^ e ; u
#                         8 g = e
#                         ` < $ y
#                         a f l ;
#                         3 n ; *
#                         * K _ A
#                         I p E k
#                         b m S a
#                         L \ # 7
#                         ( & ; e
#                         - # c %
#                         D f C ?
#                         9 4 L j
#                         5 m @ j
#                         p E * M
#                         H % B 2
#                         h ^ J 6
#                         0 ~ # t
#                         L o 5 [
#                         P ! ) Q
#                         p n e x
#                         X ! z :
#                         & / 1 "
# ...
