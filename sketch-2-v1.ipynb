# %% [markdown]
# I started off by using the polygon example for my homework. The concept for my concrete poem was to show oppression to organization(taking action against oppression). The work below is a first version of the idea that I had. The next steps would be to make it into an animation.

# %%
import random
import math

# %%
from IPython.display import display, HTML
def show_html(src):
    return display(HTML(src), metadata=dict(isolated=True))

# %%
html_tmpl = """<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="utf-8">
    <title>{title}</title>
    <style>
    html {{ min-height: 32em; overflow: hidden; }}
    </style>
</head>
<body>
{content}
</body>
</html>"""

# %%
src = open("oppressed.txt").read()
#letters = list(src)
#src = ["organized", "organized", "organized", "organized", "organized", "organized", "organized", "organized"]
letters = list(src)
grid_size = int(math.sqrt(len(letters)))
current_index = 0
divs = []
for i in range(grid_size):
    for j in range(grid_size):
        x_pos = 5 + (90 / grid_size) * i
        y_pos = 5 + (50 / (grid_size)) * j
        this_div = mkdiv(letters[current_index],
                         top=f"{x_pos}%",
                         left=f"{y_pos}%",
                         font_family="Courier",
                         font_size="16pt",
                         #font_size=f"{random.randrange(4, 48)}",
                         transform="translate(-50%, -50%)")
        divs.append(this_div)
        current_index += 1
html_src = html_tmpl.format(title="frost grid", content="".join(divs))
show_html(html_src)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <title>frost grid</title>
#     <style>
#     html { min-height: 32em; overflow: hidden; }
#     </style>
# </head>
# <body>
# <div style='top: 5.0%; left: 5.0%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>o</div><div style='top: 5.0%; left: 10.555555555555555%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>p</div><div style='top: 5.0%; left: 16.11111111111111%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>p</div><div style='top: 5.0%; left: 21.666666666666664%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>r</div><div style='top: 5.0%; left: 27.22222222222222%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>e</div><div style='top: 5.0%; left: 32.77777777777778%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>s</div><div style='top: 5.0%; left: 38.33333333333333%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>s</div><div style='top: 5.0%; left: 43.888888888888886%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>e</div><div style='top: 5.0%; left: 49.44444444444444%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>d</div><div style='top: 15.0%; left: 5.0%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>o</div><div style='top: 15.0%; left: 10.555555555555555%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 15.0%; left: 16.11111111111111%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 15.0%; left: 21.666666666666664%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 15.0%; left: 27.22222222222222%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 15.0%; left: 32.77777777777778%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 15.0%; left: 38.33333333333333%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 15.0%; left: 43.888888888888886%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 15.0%; left: 49.44444444444444%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>d</div><div style='top: 25.0%; left: 5.0%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>o</div><div style='top: 25.0%; left: 10.555555555555555%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 25.0%; left: 16.11111111111111%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 25.0%; left: 21.666666666666664%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 25.0%; left: 27.22222222222222%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 25.0%; left: 32.77777777777778%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 25.0%; left: 38.33333333333333%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 25.0%; left: 43.888888888888886%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 25.0%; left: 49.44444444444444%; font-family: Courier; font-size: 16pt; transform: translate(-50%,  ...

# %%
src = open("oppressed1.txt").read()
#letters = list(src)
#src = ["organized", "organized", "organized", "organized", "organized", "organized", "organized", "organized"]
letters = list(src)
grid_size = int(math.sqrt(len(letters)))
current_index = 0
divs = []
for i in range(grid_size):
    for j in range(grid_size):
        x_pos = 5 + (90 / grid_size) * i
        y_pos = 5 + (50 / (grid_size)) * j
        this_div = mkdiv(letters[current_index],
                         top=f"{x_pos}%",
                         left=f"{y_pos}%",
                         font_family="Courier",
                         font_size="16pt",
                         #font_size=f"{random.randrange(4, 48)}",
                         transform="translate(-50%, -50%)")
        divs.append(this_div)
        current_index += 1
html_src = html_tmpl.format(title="frost grid", content="".join(divs))
show_html(html_src)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <title>frost grid</title>
#     <style>
#     html { min-height: 32em; overflow: hidden; }
#     </style>
# </head>
# <body>
# <div style='top: 5.0%; left: 5.0%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 5.0%; left: 10.555555555555555%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 5.0%; left: 16.11111111111111%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 5.0%; left: 21.666666666666664%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 5.0%; left: 27.22222222222222%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 5.0%; left: 32.77777777777778%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 5.0%; left: 38.33333333333333%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 5.0%; left: 43.888888888888886%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 5.0%; left: 49.44444444444444%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 15.0%; left: 5.0%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>o</div><div style='top: 15.0%; left: 10.555555555555555%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>p</div><div style='top: 15.0%; left: 16.11111111111111%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>p</div><div style='top: 15.0%; left: 21.666666666666664%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>r</div><div style='top: 15.0%; left: 27.22222222222222%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>e</div><div style='top: 15.0%; left: 32.77777777777778%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>s</div><div style='top: 15.0%; left: 38.33333333333333%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>s</div><div style='top: 15.0%; left: 43.888888888888886%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>e</div><div style='top: 15.0%; left: 49.44444444444444%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>d</div><div style='top: 25.0%; left: 5.0%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>o</div><div style='top: 25.0%; left: 10.555555555555555%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 25.0%; left: 16.11111111111111%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 25.0%; left: 21.666666666666664%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 25.0%; left: 27.22222222222222%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 25.0%; left: 32.77777777777778%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 25.0%; left: 38.33333333333333%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 25.0%; left: 43.888888888888886%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 25.0%; left: 49.44444444444444%; font-family: Courier; font-size: 16pt; transform: translate(-50%,  ...

# %%
src = open("oppressed2.txt").read()
#letters = list(src)
#src = ["organized", "organized", "organized", "organized", "organized", "organized", "organized", "organized"]
letters = list(src)
grid_size = int(math.sqrt(len(letters)))
current_index = 0
divs = []
for i in range(grid_size):
    for j in range(grid_size):
        x_pos = 5 + (90 / grid_size) * i
        y_pos = 5 + (50 / (grid_size)) * j
        this_div = mkdiv(letters[current_index],
                         top=f"{x_pos}%",
                         left=f"{y_pos}%",
                         font_family="Courier",
                         font_size="16pt",
                         #font_size=f"{random.randrange(4, 48)}",
                         transform="translate(-50%, -50%)")
        divs.append(this_div)
        current_index += 1
html_src = html_tmpl.format(title="frost grid", content="".join(divs))
show_html(html_src)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <title>frost grid</title>
#     <style>
#     html { min-height: 32em; overflow: hidden; }
#     </style>
# </head>
# <body>
# <div style='top: 5.0%; left: 5.0%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 5.0%; left: 10.555555555555555%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 5.0%; left: 16.11111111111111%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 5.0%; left: 21.666666666666664%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 5.0%; left: 27.22222222222222%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 5.0%; left: 32.77777777777778%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 5.0%; left: 38.33333333333333%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 5.0%; left: 43.888888888888886%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 5.0%; left: 49.44444444444444%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 15.0%; left: 5.0%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 15.0%; left: 10.555555555555555%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 15.0%; left: 16.11111111111111%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 15.0%; left: 21.666666666666664%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 15.0%; left: 27.22222222222222%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 15.0%; left: 32.77777777777778%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 15.0%; left: 38.33333333333333%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 15.0%; left: 43.888888888888886%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 15.0%; left: 49.44444444444444%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 25.0%; left: 5.0%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>o</div><div style='top: 25.0%; left: 10.555555555555555%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>p</div><div style='top: 25.0%; left: 16.11111111111111%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>p</div><div style='top: 25.0%; left: 21.666666666666664%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>r</div><div style='top: 25.0%; left: 27.22222222222222%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>e</div><div style='top: 25.0%; left: 32.77777777777778%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>s</div><div style='top: 25.0%; left: 38.33333333333333%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>s</div><div style='top: 25.0%; left: 43.888888888888886%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>e</div><div style='top: 25.0%; left: 49.44444444444444%; font-family: Courier; font-size: 16pt; transform: translate(-50%,  ...

# %%
src = open("oppressed3.txt").read()
#letters = list(src)
#src = ["organized", "organized", "organized", "organized", "organized", "organized", "organized", "organized"]
letters = list(src)
grid_size = int(math.sqrt(len(letters)))
current_index = 0
divs = []
for i in range(grid_size):
    for j in range(grid_size):
        x_pos = 5 + (90 / grid_size) * i
        y_pos = 5 + (50 / (grid_size)) * j
        this_div = mkdiv(letters[current_index],
                         top=f"{x_pos}%",
                         left=f"{y_pos}%",
                         font_family="Courier",
                         font_size="16pt",
                         #font_size=f"{random.randrange(4, 48)}",
                         transform="translate(-50%, -50%)")
        divs.append(this_div)
        current_index += 1
html_src = html_tmpl.format(title="frost grid", content="".join(divs))
show_html(html_src)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <title>frost grid</title>
#     <style>
#     html { min-height: 32em; overflow: hidden; }
#     </style>
# </head>
# <body>
# <div style='top: 5.0%; left: 5.0%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 5.0%; left: 10.555555555555555%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 5.0%; left: 16.11111111111111%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 5.0%; left: 21.666666666666664%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 5.0%; left: 27.22222222222222%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 5.0%; left: 32.77777777777778%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 5.0%; left: 38.33333333333333%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 5.0%; left: 43.888888888888886%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 5.0%; left: 49.44444444444444%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 15.0%; left: 5.0%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 15.0%; left: 10.555555555555555%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 15.0%; left: 16.11111111111111%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 15.0%; left: 21.666666666666664%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 15.0%; left: 27.22222222222222%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 15.0%; left: 32.77777777777778%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 15.0%; left: 38.33333333333333%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 15.0%; left: 43.888888888888886%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 15.0%; left: 49.44444444444444%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 25.0%; left: 5.0%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 25.0%; left: 10.555555555555555%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 25.0%; left: 16.11111111111111%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 25.0%; left: 21.666666666666664%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 25.0%; left: 27.22222222222222%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 25.0%; left: 32.77777777777778%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 25.0%; left: 38.33333333333333%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 25.0%; left: 43.888888888888886%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 25.0%; left: 49.44444444444444%; font-family: Courier; font-size: 16pt; transform: translate(-50%,  ...

# %%
src = open("oppressed4.txt").read()
#letters = list(src)
#src = ["organized", "organized", "organized", "organized", "organized", "organized", "organized", "organized"]
letters = list(src)
grid_size = int(math.sqrt(len(letters)))
current_index = 0
divs = []
for i in range(grid_size):
    for j in range(grid_size):
        x_pos = 5 + (90 / grid_size) * i
        y_pos = 5 + (50 / (grid_size)) * j
        this_div = mkdiv(letters[current_index],
                         top=f"{x_pos}%",
                         left=f"{y_pos}%",
                         font_family="Courier",
                         font_size="16pt",
                         #font_size=f"{random.randrange(4, 48)}",
                         transform="translate(-50%, -50%)")
        divs.append(this_div)
        current_index += 1
html_src = html_tmpl.format(title="frost grid", content="".join(divs))
show_html(html_src)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <title>frost grid</title>
#     <style>
#     html { min-height: 32em; overflow: hidden; }
#     </style>
# </head>
# <body>
# <div style='top: 5.0%; left: 5.0%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 5.0%; left: 10.555555555555555%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 5.0%; left: 16.11111111111111%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 5.0%; left: 21.666666666666664%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 5.0%; left: 27.22222222222222%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 5.0%; left: 32.77777777777778%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 5.0%; left: 38.33333333333333%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 5.0%; left: 43.888888888888886%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 5.0%; left: 49.44444444444444%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 15.0%; left: 5.0%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 15.0%; left: 10.555555555555555%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 15.0%; left: 16.11111111111111%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 15.0%; left: 21.666666666666664%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 15.0%; left: 27.22222222222222%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 15.0%; left: 32.77777777777778%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 15.0%; left: 38.33333333333333%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 15.0%; left: 43.888888888888886%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 15.0%; left: 49.44444444444444%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 25.0%; left: 5.0%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 25.0%; left: 10.555555555555555%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 25.0%; left: 16.11111111111111%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 25.0%; left: 21.666666666666664%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 25.0%; left: 27.22222222222222%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 25.0%; left: 32.77777777777778%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 25.0%; left: 38.33333333333333%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 25.0%; left: 43.888888888888886%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 25.0%; left: 49.44444444444444%; font-family: Courier; font-size: 16pt; transform: translate(-50%,  ...

# %%
src = open("oppressed5.txt").read()
#letters = list(src)
#src = ["organized", "organized", "organized", "organized", "organized", "organized", "organized", "organized"]
letters = list(src)
grid_size = int(math.sqrt(len(letters)))
current_index = 0
divs = []
for i in range(grid_size):
    for j in range(grid_size):
        x_pos = 5 + (90 / grid_size) * i
        y_pos = 5 + (50 / (grid_size)) * j
        this_div = mkdiv(letters[current_index],
                         top=f"{x_pos}%",
                         left=f"{y_pos}%",
                         font_family="Courier",
                         font_size="16pt",
                         #font_size=f"{random.randrange(4, 48)}",
                         transform="translate(-50%, -50%)")
        divs.append(this_div)
        current_index += 1
html_src = html_tmpl.format(title="frost grid", content="".join(divs))
show_html(html_src)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <title>frost grid</title>
#     <style>
#     html { min-height: 32em; overflow: hidden; }
#     </style>
# </head>
# <body>
# <div style='top: 5.0%; left: 5.0%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 5.0%; left: 10.555555555555555%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 5.0%; left: 16.11111111111111%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 5.0%; left: 21.666666666666664%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 5.0%; left: 27.22222222222222%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 5.0%; left: 32.77777777777778%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 5.0%; left: 38.33333333333333%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 5.0%; left: 43.888888888888886%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 5.0%; left: 49.44444444444444%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 15.0%; left: 5.0%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 15.0%; left: 10.555555555555555%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 15.0%; left: 16.11111111111111%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 15.0%; left: 21.666666666666664%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 15.0%; left: 27.22222222222222%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 15.0%; left: 32.77777777777778%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 15.0%; left: 38.33333333333333%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 15.0%; left: 43.888888888888886%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 15.0%; left: 49.44444444444444%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 25.0%; left: 5.0%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>o</div><div style='top: 25.0%; left: 10.555555555555555%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>p</div><div style='top: 25.0%; left: 16.11111111111111%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>p</div><div style='top: 25.0%; left: 21.666666666666664%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>r</div><div style='top: 25.0%; left: 27.22222222222222%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>e</div><div style='top: 25.0%; left: 32.77777777777778%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>s</div><div style='top: 25.0%; left: 38.33333333333333%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>s</div><div style='top: 25.0%; left: 43.888888888888886%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>e</div><div style='top: 25.0%; left: 49.44444444444444%; font-family: Courier; font-size: 16pt; transform: translate(-50%,  ...

# %%
src = open("oppressed6.txt").read()
#letters = list(src)
#src = ["organized", "organized", "organized", "organized", "organized", "organized", "organized", "organized"]
letters = list(src)
grid_size = int(math.sqrt(len(letters)))
current_index = 0
divs = []
for i in range(grid_size):
    for j in range(grid_size):
        x_pos = 5 + (90 / grid_size) * i
        y_pos = 5 + (50 / (grid_size)) * j
        this_div = mkdiv(letters[current_index],
                         top=f"{x_pos}%",
                         left=f"{y_pos}%",
                         font_family="Courier",
                         font_size="16pt",
                         #font_size=f"{random.randrange(4, 48)}",
                         transform="translate(-50%, -50%)")
        divs.append(this_div)
        current_index += 1
html_src = html_tmpl.format(title="frost grid", content="".join(divs))
show_html(html_src)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <title>frost grid</title>
#     <style>
#     html { min-height: 32em; overflow: hidden; }
#     </style>
# </head>
# <body>
# <div style='top: 5.0%; left: 5.0%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 5.0%; left: 10.555555555555555%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 5.0%; left: 16.11111111111111%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 5.0%; left: 21.666666666666664%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 5.0%; left: 27.22222222222222%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 5.0%; left: 32.77777777777778%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 5.0%; left: 38.33333333333333%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 5.0%; left: 43.888888888888886%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 5.0%; left: 49.44444444444444%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'> </div><div style='top: 15.0%; left: 5.0%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>o</div><div style='top: 15.0%; left: 10.555555555555555%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>p</div><div style='top: 15.0%; left: 16.11111111111111%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>p</div><div style='top: 15.0%; left: 21.666666666666664%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>r</div><div style='top: 15.0%; left: 27.22222222222222%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>e</div><div style='top: 15.0%; left: 32.77777777777778%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>s</div><div style='top: 15.0%; left: 38.33333333333333%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>s</div><div style='top: 15.0%; left: 43.888888888888886%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>e</div><div style='top: 15.0%; left: 49.44444444444444%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>d</div><div style='top: 25.0%; left: 5.0%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>o</div><div style='top: 25.0%; left: 10.555555555555555%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>r</div><div style='top: 25.0%; left: 16.11111111111111%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>g</div><div style='top: 25.0%; left: 21.666666666666664%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>a</div><div style='top: 25.0%; left: 27.22222222222222%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>n</div><div style='top: 25.0%; left: 32.77777777777778%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>i</div><div style='top: 25.0%; left: 38.33333333333333%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>z</div><div style='top: 25.0%; left: 43.888888888888886%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>e</div><div style='top: 25.0%; left: 49.44444444444444%; font-family: Courier; font-size: 16pt; transform: translate(-50%,  ...

# %%
src = open("oppressed7.txt").read()
#letters = list(src)
#src = ["organized", "organized", "organized", "organized", "organized", "organized", "organized", "organized"]
letters = list(src)
grid_size = int(math.sqrt(len(letters)))
current_index = 0
divs = []
for i in range(grid_size):
    for j in range(grid_size):
        x_pos = 5 + (90 / grid_size) * i
        y_pos = 5 + (50 / (grid_size)) * j
        this_div = mkdiv(letters[current_index],
                         top=f"{x_pos}%",
                         left=f"{y_pos}%",
                         font_family="Courier",
                         font_size="16pt",
                         #font_size=f"{random.randrange(4, 48)}",
                         transform="translate(-50%, -50%)")
        divs.append(this_div)
        current_index += 1
html_src = html_tmpl.format(title="frost grid", content="".join(divs))
show_html(html_src)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <title>frost grid</title>
#     <style>
#     html { min-height: 32em; overflow: hidden; }
#     </style>
# </head>
# <body>
# <div style='top: 5.0%; left: 5.0%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>o</div><div style='top: 5.0%; left: 10.555555555555555%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>p</div><div style='top: 5.0%; left: 16.11111111111111%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>p</div><div style='top: 5.0%; left: 21.666666666666664%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>r</div><div style='top: 5.0%; left: 27.22222222222222%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>e</div><div style='top: 5.0%; left: 32.77777777777778%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>s</div><div style='top: 5.0%; left: 38.33333333333333%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>s</div><div style='top: 5.0%; left: 43.888888888888886%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>e</div><div style='top: 5.0%; left: 49.44444444444444%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>d</div><div style='top: 15.0%; left: 5.0%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>o</div><div style='top: 15.0%; left: 10.555555555555555%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>r</div><div style='top: 15.0%; left: 16.11111111111111%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>g</div><div style='top: 15.0%; left: 21.666666666666664%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>a</div><div style='top: 15.0%; left: 27.22222222222222%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>n</div><div style='top: 15.0%; left: 32.77777777777778%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>i</div><div style='top: 15.0%; left: 38.33333333333333%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>z</div><div style='top: 15.0%; left: 43.888888888888886%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>e</div><div style='top: 15.0%; left: 49.44444444444444%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>d</div><div style='top: 25.0%; left: 5.0%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>o</div><div style='top: 25.0%; left: 10.555555555555555%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>r</div><div style='top: 25.0%; left: 16.11111111111111%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>g</div><div style='top: 25.0%; left: 21.666666666666664%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>a</div><div style='top: 25.0%; left: 27.22222222222222%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>n</div><div style='top: 25.0%; left: 32.77777777777778%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>i</div><div style='top: 25.0%; left: 38.33333333333333%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>z</div><div style='top: 25.0%; left: 43.888888888888886%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>e</div><div style='top: 25.0%; left: 49.44444444444444%; font-family: Courier; font-size: 16pt; transform: translate(-50%,  ...

# %%
src = open("oppressed8.txt").read()
#letters = list(src)
#src = ["organized", "organized", "organized", "organized", "organized", "organized", "organized", "organized"]
letters = list(src)
grid_size = int(math.sqrt(len(letters)))
current_index = 0
divs = []
for i in range(grid_size):
    for j in range(grid_size):
        x_pos = 5 + (90 / grid_size) * i
        y_pos = 5 + (50 / (grid_size)) * j
        this_div = mkdiv(letters[current_index],
                         top=f"{x_pos}%",
                         left=f"{y_pos}%",
                         font_family="Courier",
                         font_size="16pt",
                         #font_size=f"{random.randrange(4, 48)}",
                         transform="translate(-50%, -50%)")
        divs.append(this_div)
        current_index += 1
html_src = html_tmpl.format(title="frost grid", content="".join(divs))
show_html(html_src)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <title>frost grid</title>
#     <style>
#     html { min-height: 32em; overflow: hidden; }
#     </style>
# </head>
# <body>
# <div style='top: 5.0%; left: 5.0%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>o</div><div style='top: 5.0%; left: 10.555555555555555%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>r</div><div style='top: 5.0%; left: 16.11111111111111%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>g</div><div style='top: 5.0%; left: 21.666666666666664%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>a</div><div style='top: 5.0%; left: 27.22222222222222%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>n</div><div style='top: 5.0%; left: 32.77777777777778%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>i</div><div style='top: 5.0%; left: 38.33333333333333%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>z</div><div style='top: 5.0%; left: 43.888888888888886%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>e</div><div style='top: 5.0%; left: 49.44444444444444%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>d</div><div style='top: 15.0%; left: 5.0%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>o</div><div style='top: 15.0%; left: 10.555555555555555%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>r</div><div style='top: 15.0%; left: 16.11111111111111%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>g</div><div style='top: 15.0%; left: 21.666666666666664%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>a</div><div style='top: 15.0%; left: 27.22222222222222%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>n</div><div style='top: 15.0%; left: 32.77777777777778%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>i</div><div style='top: 15.0%; left: 38.33333333333333%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>z</div><div style='top: 15.0%; left: 43.888888888888886%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>e</div><div style='top: 15.0%; left: 49.44444444444444%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>d</div><div style='top: 25.0%; left: 5.0%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>o</div><div style='top: 25.0%; left: 10.555555555555555%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>r</div><div style='top: 25.0%; left: 16.11111111111111%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>g</div><div style='top: 25.0%; left: 21.666666666666664%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>a</div><div style='top: 25.0%; left: 27.22222222222222%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>n</div><div style='top: 25.0%; left: 32.77777777777778%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>i</div><div style='top: 25.0%; left: 38.33333333333333%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>z</div><div style='top: 25.0%; left: 43.888888888888886%; font-family: Courier; font-size: 16pt; transform: translate(-50%, -50%); position: absolute;'>e</div><div style='top: 25.0%; left: 49.44444444444444%; font-family: Courier; font-size: 16pt; transform: translate(-50%,  ...

# %%
src = open("oppressed8.txt").read()
#letters = list(src)
#src = ["organized", "organized", "organized", "organized", "organized", "organized", "organized", "organized"]
letters = list(src)
grid_size = int(math.sqrt(len(letters)))
current_index = 0
divs = []
for i in range(grid_size):
    for j in range(grid_size):
        x_pos = 5 + (90 / grid_size) * i
        y_pos = 5 + (50 / (grid_size)) * j
        this_div = mkdiv(letters[current_index],
                         top=f"{x_pos}%",
                         left=f"{y_pos}%",
                         font_family="Courier",
                         #font_size="16pt",
                         font_size=f"{random.randrange(4, 48)}",
                         transform="translate(-50%, -50%)")
        divs.append(this_div)
        current_index += 1
html_src = html_tmpl.format(title="frost grid", content="".join(divs))
show_html(html_src)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <title>frost grid</title>
#     <style>
#     html { min-height: 32em; overflow: hidden; }
#     </style>
# </head>
# <body>
# <div style='top: 5.0%; left: 5.0%; font-family: Courier; font-size: 29; transform: translate(-50%, -50%); position: absolute;'>o</div><div style='top: 5.0%; left: 10.555555555555555%; font-family: Courier; font-size: 43; transform: translate(-50%, -50%); position: absolute;'>r</div><div style='top: 5.0%; left: 16.11111111111111%; font-family: Courier; font-size: 9; transform: translate(-50%, -50%); position: absolute;'>g</div><div style='top: 5.0%; left: 21.666666666666664%; font-family: Courier; font-size: 43; transform: translate(-50%, -50%); position: absolute;'>a</div><div style='top: 5.0%; left: 27.22222222222222%; font-family: Courier; font-size: 36; transform: translate(-50%, -50%); position: absolute;'>n</div><div style='top: 5.0%; left: 32.77777777777778%; font-family: Courier; font-size: 45; transform: translate(-50%, -50%); position: absolute;'>i</div><div style='top: 5.0%; left: 38.33333333333333%; font-family: Courier; font-size: 31; transform: translate(-50%, -50%); position: absolute;'>z</div><div style='top: 5.0%; left: 43.888888888888886%; font-family: Courier; font-size: 31; transform: translate(-50%, -50%); position: absolute;'>e</div><div style='top: 5.0%; left: 49.44444444444444%; font-family: Courier; font-size: 9; transform: translate(-50%, -50%); position: absolute;'>d</div><div style='top: 15.0%; left: 5.0%; font-family: Courier; font-size: 27; transform: translate(-50%, -50%); position: absolute;'>o</div><div style='top: 15.0%; left: 10.555555555555555%; font-family: Courier; font-size: 35; transform: translate(-50%, -50%); position: absolute;'>r</div><div style='top: 15.0%; left: 16.11111111111111%; font-family: Courier; font-size: 25; transform: translate(-50%, -50%); position: absolute;'>g</div><div style='top: 15.0%; left: 21.666666666666664%; font-family: Courier; font-size: 22; transform: translate(-50%, -50%); position: absolute;'>a</div><div style='top: 15.0%; left: 27.22222222222222%; font-family: Courier; font-size: 34; transform: translate(-50%, -50%); position: absolute;'>n</div><div style='top: 15.0%; left: 32.77777777777778%; font-family: Courier; font-size: 38; transform: translate(-50%, -50%); position: absolute;'>i</div><div style='top: 15.0%; left: 38.33333333333333%; font-family: Courier; font-size: 16; transform: translate(-50%, -50%); position: absolute;'>z</div><div style='top: 15.0%; left: 43.888888888888886%; font-family: Courier; font-size: 40; transform: translate(-50%, -50%); position: absolute;'>e</div><div style='top: 15.0%; left: 49.44444444444444%; font-family: Courier; font-size: 29; transform: translate(-50%, -50%); position: absolute;'>d</div><div style='top: 25.0%; left: 5.0%; font-family: Courier; font-size: 16; transform: translate(-50%, -50%); position: absolute;'>o</div><div style='top: 25.0%; left: 10.555555555555555%; font-family: Courier; font-size: 4; transform: translate(-50%, -50%); position: absolute;'>r</div><div style='top: 25.0%; left: 16.11111111111111%; font-family: Courier; font-size: 28; transform: translate(-50%, -50%); position: absolute;'>g</div><div style='top: 25.0%; left: 21.666666666666664%; font-family: Courier; font-size: 35; transform: translate(-50%, -50%); position: absolute;'>a</div><div style='top: 25.0%; left: 27.22222222222222%; font-family: Courier; font-size: 30; transform: translate(-50%, -50%); position: absolute;'>n</div><div style='top: 25.0%; left: 32.77777777777778%; font-family: Courier; font-size: 14; transform: translate(-50%, -50%); position: absolute;'>i</div><div style='top: 25.0%; left: 38.33333333333333%; font-family: Courier; font-size: 7; transform: translate(-50%, -50%); position: absolute;'>z</div><div style='top: 25.0%; left: 43.888888888888886%; font-family: Courier; font-size: 6; transform: translate(-50%, -50%); position: absolute;'>e</div><div style='top: 25.0%; left: 49.44444444444444%; font-family: Courier; font-size: 24; transform: translate(-50%, -50%); position: absolute;'>d</div><div style='top: 35.0%;  ...

# %%
#open("trial2.html", "w").write(html_src)

# %%
#!open trial2.html
